# %%
import numpy as np
import pandas as pd

# %%
autos_raw = pd.read_csv("autos.csv",encoding = "ISO-8859-1")

# %%
autos = autos_raw[:500][['price', 'yearOfRegistration', 'gearbox', 'powerPS', 'kilometer','fuelType', 'brand', 'vehicleType']]
#powerPS == metric HP

autos['price']/=100
#price in thousand euros

autos = autos.dropna(how='any')

autos = autos.drop(autos[autos.price < 1].index)
autos = autos.drop(autos[autos.price > 1000].index)

autos = autos.drop(autos[autos.powerPS == 0].index)
autos = autos.drop(autos[autos.powerPS > 1000].index)

autos = autos.drop(autos[autos.yearOfRegistration <1990].index)

n = autos.shape[0]
print(n)
# Out:
# 362

# %% [raw]
# Metadata:
# 1)price - thousand euros;
# 2)yearOfRegistration - year;
# 3)gearbox - manuell/automatik;
# 4)powerPS - horse power;
# 5)kilometer - km;
# 6)fueltype - benzin/diesel;
# 7)brand -
# 8)vehicleType - 'andere' 'bus' 'cabrio' 'coupe' 'kleinwagen' 'kombi' 'limousine' 'suv';

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

x = 'powerPS'
y = 'price'
data = autos[[x, y]]

k = 3


k_means = KMeans(n_clusters=k).fit(data)
k_means_centers = k_means.cluster_centers_

labels = k_means.labels_


plt.title("K-means without standartization")
plt.grid()
plt.scatter(data[x], data[y], c = labels)
plt.xlabel(x)
plt.ylabel(y)
plt.scatter(k_means_centers[:,0], k_means_centers[:,1], c='r')
plt.show()

grand_mean = np.mean(k_means_centers, axis = 0)
print(grand_mean)
print(k_means_centers)
# Out:
# [ 178.82644193  145.63903888]
# [[ 173.03100775   96.74403101]
#  [  90.98165138   27.68775229]
#  [ 272.46666667  312.48533333]]

# %%
def compute_mean_std(data):
    mean = np.mean(data)
    x_i_sq = data*data
    std = (np.mean(x_i_sq) - mean**2)**(1/2)
    return mean, std


#Standartization of dataset

mean_x, std_x = compute_mean_std(data[x])
mean_y, std_y = compute_mean_std(data[y])



new_data = np.copy(data)

new_data[:,0] = (data[x]-mean_x)/std_x
new_data[:,1] = (data[y]-mean_y)/std_y

k_means = KMeans(n_clusters=k).fit(new_data)
k_means_centers = k_means.cluster_centers_

labels = k_means.labels_


plt.title("K-means with standartization")
plt.grid()
plt.scatter(new_data[:,0], new_data[:,1], c = labels)
plt.xlabel(x)
plt.ylabel(y)
plt.plot(k_means_centers[:,0], k_means_centers[:,1], 'r*')
plt.show()




grand_mean = np.mean(k_means_centers, axis = 0)
print(grand_mean)
print(k_means_centers)
# Out:
# 61.826785108 61.826785108
# [ 0.84188327  1.10562204]
# [[ 2.34083553  3.36285024]
#  [-0.60014759 -0.46077051]
#  [ 0.78496186  0.41478639]]

# %%
def bootstrap(data, m = 5000):
    n = data.shape[0]
    r = np.random.randint(0,n,(n,m))
    xr = data[r]
    mr = np.mean(xr, axis = 0)
    return mr

mr = bootstrap(np.array(data["price"][labels==0]))
mean_x, std_x = compute_mean_std(data['price'][labels==0])
print("Cluster mean =",mean_x)
print("Cluster std  =",std_x)

plt.title("Histogram of price values in the first cluster")
plt.xlabel('Value')
plt.grid()
plt.ylabel('Counts')
plt.hist(data['price'][labels==0])
plt.show()


plt.title("Bootstrap of price values in the first cluster")
plt.xlabel('Value')
plt.grid()
plt.ylabel('Counts')
plt.hist(mr)
plt.show()
# Out:
# Cluster mean = 312.485333333
# Cluster std  = 114.321778903

# %%
mr = bootstrap(np.array(data["price"][labels==2]))
mean_x, std_x = compute_mean_std(data['price'][labels==2])
print("Cluster mean =",mean_x)
print("Cluster std  =",std_x)

plt.title("Histogram of price values in the third cluster")
plt.xlabel('Value')
plt.grid()
plt.ylabel('Counts')
plt.hist(data['price'][labels==2])
plt.show()


plt.title("Bootstrap of price values in the third cluster")
plt.xlabel('Value')
plt.grid()
plt.ylabel('Counts')
plt.hist(mr)
plt.show()
# Out:
# Cluster mean = 94.73432
# Cluster std  = 49.9706392889

# %%
#assignment 4

# %%
#assignment 6

# %%
x = autos['yearOfRegistration'][autos['price']<=300]
y = autos['price'][autos['price']<=300]
#x = 2016 - x
plt.xlabel("year of registration")
plt.ylabel("price")
plt.plot(x, y, "*b")
plt.show()
c = np.corrcoef(x,y)
rho = c[0,1]
print(rho)
det = rho**2
print(det) #hight enough as Mirkin said if its value about 0.5

slope = rho*np.std(y)/np.std(x)
print("slope :",slope)
print("При уменьшении возраста машины на 1 год, цена увеличивается на 7 евро")
intercept = np.mean(y)-slope*np.mean(x)  #y = slope*x + instercept

print("intercept :", intercept) #better not to tell anything about intercept
yc = slope*x + intercept

plt.xlabel("year of registration")
plt.ylabel("price")
plt.plot(x, y, "*b", x, yc, "-r")
plt.show()


indexes = np.array([1,34,50,75,100])
xf = x[indexes]
yf = y[indexes]
ycf = yc[indexes]

error = 100*(ycf-yf)/yf
error2 = 100*(yc-y)/y
print(np.mean(error2))
# Out:
# 0.701774145665
# 0.492486951524
# slope : 7.25854188734
# При уменьшении возраста машины на 1 год, цена увеличивается на 7 евро
# intercept : -14484.890162
# 40.6991818543

# %%
a = np.random.randint(0,4,(2,3))
b = np.array([3,2,1,0])
print(a)
print(b[a])
